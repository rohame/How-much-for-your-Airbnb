# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk
% matplotlib inline
# Always make it pretty.
plt.style.use('ggplot')

# %%
df = pd.read_csv('cleaned_data.csv')

# %%
df.head(10)
# Out:
#    price  security_deposit  cleaning_fee  beds  host_response_time  \
# 0     45               150            50     1                   0
# 1     95               150            50     1                   4
# 2     60               150            30     1                   2
# 3     70               150            20     1                   2
# 4    104               150            60     1                   2
# 5     90               150            50     1                   0
# 6    374               250           200     5                   0
# 7    100               100            30     3                   0
# 8     60               100            20     2                   4
# 9    175                 0           100     1                   0
#
#    host_is_superhost neighbourhood_group_cleansed   latitude  longitude  \
# 0                  0                       Queens  40.754444 -73.895933
# 1                  1                    Manhattan  40.785097 -73.942337
# ...

# %%
response_rate = df['host_response_rate']

# %%
rates = list(response_rate)
print(type(rates[0]))
# Out:
# <class 'int'>

# %%
new_rate = []
for rate in rates:
    if type(rate) == str:
        rate_list = list(rate)[:-1]
        rate_perc = 0
        for i in range(len(rate_list)):
            rate_perc += int(rate_list[i])*(10**(len(rate_list)-i-1))
        new_rate.append(rate_perc)
    if type(rate) == float:
        new_rate.append(rate)

# %%
df['host_response_rate'] = pd.DataFrame(new_rate)

# %%
df.head(10)
# Out:
#    price  security_deposit  cleaning_fee  beds  host_response_time  \
# 0     45               150            50     1                   0
# 1     95               150            50     1                   4
# 2     60               150            30     1                   2
# 3     70               150            20     1                   2
# 4    104               150            60     1                   2
# 5     90               150            50     1                   0
# 6    374               250           200     5                   0
# 7    100               100            30     3                   0
# 8     60               100            20     2                   4
# 9    175                 0           100     1                   0
#
#    host_is_superhost neighbourhood_group_cleansed   latitude  longitude  \
# 0                  0                       Queens  40.754444 -73.895933
# 1                  1                    Manhattan  40.785097 -73.942337
# ...

# %%
df.to_csv('cleaned_data.csv',index=False,sep=',')
